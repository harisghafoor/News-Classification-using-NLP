# %% [markdown]
# # Introduction:
# In this project, we are going to predict the category of news article by using NLP techniques. We started off from cleaning the dataset and pre-processing the feature space. In EDA, we found the word length of each article to gain some insights and then we found the most repititive word and their importance in the articles using word-cloud. The word embedding technique also play very important role and as instructed we employed TF-IDF technique for converting text into integers. Then we built different predictive models and trained our dataset. Evaluation metrics play very important role because of the nature of dataset. As we can see in the EDA that our dataset is highly imbalanced so we cant use classification accuracy but we will use confusion matrix and classification report in order to evaluate the dataset. Our best performing models are Decision Trees,xGBclassifier and Multinomial Naive Bayes.

# %% [markdown]
# # Part 1: Pre-Processing of Dataset

# %% [markdown]
# ### Importing the Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import seaborn as sns
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud ,STOPWORDS
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn import svm
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
import xgboost 
from sklearn import metrics
import time
from nltk.tokenize import word_tokenize 
import re
import warnings
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ### Importing the Dataset from local Repository

# %%
# !git clone https://github.com/harisghafoor/Dataset.git
# Out:
# Cloning into 'Dataset'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 10 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (10/10), done.

# %% [markdown]
# ### Loading the Dataset

# %%
df=pd.read_csv("Dataset/Huff_news.csv")
df.head()
# Out:
#    Unnamed: 0                                            authors   category  \
# 0           0                                     Rahel Gebreyes      MEDIA
# 1           1                          Paul Brandeis Raushenbush   RELIGION
# 2           2                                       Kimberly Yam  GOOD NEWS
# 3           3  Brad Puet, ContributorStreet and documentary p...       ARTS
# 4           4                    Aimee Heckel, ContributorWriter     COMEDY
#
#          date                                           headline  \
# 0  31/01/2015  HuffPost's DC Chief Responds To Obama's Warnin...
# 1  31/01/2015             Sexism: The Original Sin Of The Church
# 2  31/01/2015  Banksy Exhibit Inspires Ex-Drug Addict To Chan...
# 3  31/01/2015                                 Spirit of the Hawk
# 4  31/01/2015       The Surprising Use for Big Lots Reward Cards
#
#                                                 link  \
# 0  https://www.huffingtonpost.com/entry/obama-cri...
# 1  https://www.huffingtonpost.com/entry/sexism-ch...
# 2  https://www.huffingtonpost.com/entry/jps-banks...
# 3  https://www.huffingtonpost.com/entry/spirit-of...
# 4  https://www.huffingtonpost.com/entry/the-surpr...
#
#                                    short_description
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Dear Husband, I hope you enjoy your lunch. I m...

# %% [markdown]
# ### Merging the Short Description and Headline

# %% [markdown]
# As instructed we merge these two features to make a new feature so now we dont need to handle the missing values of short description column due to merging with the title.

# %%
df["text_all"]=df["headline"].astype(str)+ " "+df["short_description"].astype(str)
df.head()
# Out:
#    Unnamed: 0                                            authors   category  \
# 0           0                                     Rahel Gebreyes      MEDIA
# 1           1                          Paul Brandeis Raushenbush   RELIGION
# 2           2                                       Kimberly Yam  GOOD NEWS
# 3           3  Brad Puet, ContributorStreet and documentary p...       ARTS
# 4           4                    Aimee Heckel, ContributorWriter     COMEDY
#
#          date                                           headline  \
# 0  31/01/2015  HuffPost's DC Chief Responds To Obama's Warnin...
# 1  31/01/2015             Sexism: The Original Sin Of The Church
# 2  31/01/2015  Banksy Exhibit Inspires Ex-Drug Addict To Chan...
# 3  31/01/2015                                 Spirit of the Hawk
# 4  31/01/2015       The Surprising Use for Big Lots Reward Cards
#
#                                                 link  \
# 0  https://www.huffingtonpost.com/entry/obama-cri...
# 1  https://www.huffingtonpost.com/entry/sexism-ch...
# 2  https://www.huffingtonpost.com/entry/jps-banks...
# 3  https://www.huffingtonpost.com/entry/spirit-of...
# 4  https://www.huffingtonpost.com/entry/the-surpr...
#
#                                    short_description  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Dear Husband, I hope you enjoy your lunch. I m...
#
#                                             text_all
# 0  HuffPost's DC Chief Responds To Obama's Warnin...
# 1         Sexism: The Original Sin Of The Church nan
# 2  Banksy Exhibit Inspires Ex-Drug Addict To Chan...
# 3                             Spirit of the Hawk nan
# 4  The Surprising Use for Big Lots Reward Cards D...

# %% [markdown]
# ### Feature Engineering:
# We dont want to make our model complex so we will drop the columns which dont have any essential impact on the target variable. For example, the author name,date and link are not important so we will drop these features.

# %%
df.drop(['Unnamed: 0','headline','link','authors','short_description','date'],axis=1,inplace=True)
df.head()
# Out:
#     category                                           text_all
# 0      MEDIA  HuffPost's DC Chief Responds To Obama's Warnin...
# 1   RELIGION         Sexism: The Original Sin Of The Church nan
# 2  GOOD NEWS  Banksy Exhibit Inspires Ex-Drug Addict To Chan...
# 3       ARTS                             Spirit of the Hawk nan
# 4     COMEDY  The Surprising Use for Big Lots Reward Cards D...

# %% [markdown]
# # Part 2:  Exploratory data analysis

# %%
df.dtypes  # Checking the data types of the variables
# Out:
# category    object
# text_all    object
# dtype: object

# %% [markdown]
# Analyzing the no of artilces of each category in our dataset.

# %%
labels = df.groupby('category')
print("total categories:", labels.ngroups)
print(labels.size())
# Out:
# total categories: 27
# category
# ARTS               879
# BLACK VOICES       435
# BUSINESS          1468
# COLLEGE            426
# COMEDY             639
# CRIME              542
# EDUCATION          361
# ENTERTAINMENT     2172
# FIFTY              729
# GOOD NEWS          340
# GREEN              881
# HEALTHY LIVING    2245
# IMPACT            1070
# LATINO VOICES      136
# MEDIA              528
# PARENTS           1043
# POLITICS          3539
# QUEER VOICES       899
# RELIGION           901
# SCIENCE            389
# SPORTS             809
# STYLE              603
# TASTE              582
# TRAVEL             787
# WEIRD NEWS         361
# WOMEN              832
# WORLDPOST         1404
# dtype: int64

# %%
df.isnull().any() # Checking the missing values
# Out:
# category    False
# text_all    False
# dtype: bool

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(24, 10))  
# drawing the plot
sns.countplot(df.category)
plt.show()

# %% [markdown]
# As we can see in the above plot that data is highly imbalanced . So we need to use proper evaluation metrics. We have the option of upsampling the dataset by SMOTE but according to the literature review, upsampling will overfit the data and will destroy the generealization of our models on valuation sets.

# %% [markdown]
# ### Wordcloud
# We will see the important and popular words in our dataset and visualize them using library wordcloud.

# %%
df#.Text_processed
# Out:
#              category                                           text_all
# 0               MEDIA  HuffPost's DC Chief Responds To Obama's Warnin...
# 1            RELIGION         Sexism: The Original Sin Of The Church nan
# 2           GOOD NEWS  Banksy Exhibit Inspires Ex-Drug Addict To Chan...
# 3                ARTS                             Spirit of the Hawk nan
# 4              COMEDY  The Surprising Use for Big Lots Reward Cards D...
# ...               ...                                                ...
# 24995           WOMEN         Why I Thought I'd Never Live To See 33 nan
# 24996           TASTE  Five Tips For Cooking For One I often hear peo...
# 24997           CRIME  Police Want your Home Video Surveillance Foota...
# 24998           MEDIA                          Ouch, Natalie Morales nan
# 24999  HEALTHY LIVING  Reasons Not to Be Happy Our thoughts and feeli...
#
# [25000 rows x 2 columns]

# %%
text = " ".join(df.text_all)
wordcloud = WordCloud().generate(text)
plt.figure()
plt.subplots(figsize=(20,12))
wordcloud = WordCloud(
    background_color="white",
    max_words=len(text),
    max_font_size=40,
    relative_scaling=.5).generate(text)
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Cleaning the Dataset
# First we will remove all the unwanted spaces, punctuation, numbers and special characters using the fucntion made by [(https://github.com/DiveshRKubal)]. We downloaded the stopwords from library nltk and tokenize our text.

# %%
def process_text(text):
    text = text.lower().replace('\n',' ').replace('\r','').strip()
    text = re.sub(' +', ' ', text)
    text = re.sub(r'[^\w\s]','',text)  
    stop_words = set(stopwords.words('english')) 
    word_tokens = word_tokenize(text) 
    filtered_sentence = [w for w in word_tokens if not w in stop_words] 
    text = " ".join(filtered_sentence)
    return text

# %%
df['Text_processed'] = df['text_all'].apply(process_text)
df.head()
# Out:
#     category                                           text_all  \
# 0      MEDIA  HuffPost's DC Chief Responds To Obama's Warnin...
# 1   RELIGION         Sexism: The Original Sin Of The Church nan
# 2  GOOD NEWS  Banksy Exhibit Inspires Ex-Drug Addict To Chan...
# 3       ARTS                             Spirit of the Hawk nan
# 4     COMEDY  The Surprising Use for Big Lots Reward Cards D...
#
#                                       Text_processed
# 0  huffposts dc chief responds obamas warning rea...
# 1                     sexism original sin church nan
# 2  banksy exhibit inspires exdrug addict change l...
# 3                                    spirit hawk nan
# 4  surprising use big lots reward cards dear husb...

# %% [markdown]
# ## Label Encoding the Target Variable
# In order to convert the target variable into 'int' data types, we can perform one hot encoding, label encoding etc. The reason of choosing it is that label encoding is computationally efficient and takes less time than one hot encoding.

# %%
from sklearn import preprocessing 
label_encoder = preprocessing.LabelEncoder() 
df['Category_encoded']= label_encoder.fit_transform(df['category']) 
df.head()
# Out:
#     category                                           text_all  \
# 0      MEDIA  HuffPost's DC Chief Responds To Obama's Warnin...
# 1   RELIGION         Sexism: The Original Sin Of The Church nan
# 2  GOOD NEWS  Banksy Exhibit Inspires Ex-Drug Addict To Chan...
# 3       ARTS                             Spirit of the Hawk nan
# 4     COMEDY  The Surprising Use for Big Lots Reward Cards D...
#
#                                       Text_processed  Category_encoded
# 0  huffposts dc chief responds obamas warning rea...                14
# 1                     sexism original sin church nan                18
# 2  banksy exhibit inspires exdrug addict change l...                 9
# 3                                    spirit hawk nan                 0
# 4  surprising use big lots reward cards dear husb...                 4

# %%
df.to_csv('Dataset/cleaned_data.csv') # Saving the cleaned dataset.

# %% [markdown]
# ### Word Embedding Technique:
# Now converting text into numbers using TF-IDF method. There are many parameters that we havent specified just to make our analysis open and tune them later if needed.

# %%
X=df.Text_processed
Y=df.Category_encoded
X.dtype,Y.dtype
# Out:
# (dtype('O'), dtype('int64'))

# %%
tf_vec = TfidfVectorizer()
X_features = tf_vec.fit(X)
X_features = tf_vec.transform(X)
print(X_features[0:10][0:10])
# Out:
#   (0, 36345)	0.35022822842117257
#   (0, 30746)	0.36024398084413795
#   (0, 28242)	0.3748183210823089
#   (0, 27323)	0.2938436247425586
#   (0, 23291)	0.30126477695975756
#   (0, 22375)	0.0796855353721573
#   (0, 16293)	0.4424616195736056
#   (0, 8843)	0.340105117884757
#   (0, 6367)	0.33492922576339396
#   (1, 30671)	0.5385138903147262
#   (1, 30122)	0.5274362223925454
#   (1, 23828)	0.48805631068542354
#   (1, 22375)	0.10837079457046059
#   (1, 6526)	0.42646292890552734
#   (2, 22375)	0.07526357211886812
#   (2, 19511)	0.18230648265058202
#   (2, 17289)	0.37399817156791726
#   (2, 11991)	0.37399817156791726
#   (2, 11953)	0.4670912605536128
#   (2, 6130)	0.21234346965680848
#   (2, 3383)	0.43606023089171425
#   (2, 2619)	0.2527633336097971
#   (2, 1214)	0.4050292012298158
#   (3, 31632)	0.5911729242179302
#   (3, 22375)	0.14295558996840188
#   :	:
#   (9, 35794)	0.343883416103843
#   (9, 34848)	0.17605253730839643
#   (9, 33118)	0.1233547092498198
#   (9, 33106)	0.10165990169576292
#   (9, 32640)	0.1448534749186033
#   (9, 31584)	0.2935964369876087
#   (9, 29740)	0.10455852487971856
#   (9, 28703)	0.2991768481713628
#   (9, 28498)	0.1489363607376988
#   (9, 20120)	0.19466420602288553
#   (9, 20118)	0.22449233067594526
#   (9, 19731)	0.11246158341618245
#   (9, 19177)	0.22449233067594526
#   (9, 19175)	0.22449233067594526
#   (9, 19040)	0.18113878315663628
#   (9, 17255)	0.2706936107075037
#   (9, 15084)	0.14119785184885783
#   (9, 15021)	0.14738774698094959
#   (9, 14302)	0.1921299339605392
#   (9, 12071)	0.16057957488958433
#   (9, 11938)	0.1648360813698258
#   (9, 9709)	0.2095782683494154
#   (9, 3950)	0.10556141446599655
#   (9, 2904)	0.18262326439568777
#   (9, 360)	0.12685153865596796

# %% [markdown]
# # Part 3: Model Building and Evaluation

# %%
x_train, x_test, y_train, y_test = train_test_split(X_features, 
                                                    df['Category_encoded'], 
                                                    test_size=0.25, 
                                                    random_state=8)

# %% [markdown]
# We used the following script from [(https://github.com/nadaalay/News-Articles-Categorization)]. There is a general fucntion which takes multiple models to fit the training data and then make some predictions.

# %%
def fit_eval_model(model, train_features, y_train, test_features, y_test):
    
    """
    Function: train and evaluate a machine learning classifier.
    Args:
      model: machine learning classifier
      train_features: train data extracted features
      y_train: train data lables
      test_features: train data extracted features
      y_test: train data lables
    Return:
      results(dictionary): a dictionary of the model training time and classification report
    """
    results ={}
    
    # Start time
    start = time.time()
    # Train the model
    model.fit(train_features, y_train)
    # End time
    end = time.time()
    # Calculate the training time
    results['train_time'] = end - start
    
    # Test the model
    train_predicted = model.predict(train_features)
    test_predicted = model.predict(test_features)
    
     # Classification report
    results['classification_report'] = classification_report(y_test, test_predicted)
        
    return results

# %%
sv = svm.SVC()
ab = AdaBoostClassifier(random_state = 1)
gb = GradientBoostingClassifier(random_state = 1)
xgb = xgboost.XGBClassifier(random_state = 1)
tree = DecisionTreeClassifier()
nb = MultinomialNB()


# Fit and evaluate models
results = {}
for cls in [sv, ab, gb, xgb, tree, nb]:
    cls_name = cls.__class__.__name__
    results[cls_name] = {}
    results[cls_name] = fit_eval_model(cls, x_train, y_train, x_test, y_test)

# %%
for res in results:
    print (res)
    print()
    for i in results[res]:
        print (i, ':')
        print(results[res][i])
        print()
    print ('-----')
    print()
# Out:
# SVC
#
# train_time :
# 147.55914688110352
#
# classification_report :
#               precision    recall  f1-score   support
#
#            0       0.71      0.26      0.38       201
#            1       0.62      0.11      0.19       117
#            2       0.72      0.37      0.49       405
#            3       0.60      0.30      0.40       100
#            4       0.71      0.10      0.17       153
#            5       0.60      0.27      0.37       141
#            6       0.68      0.27      0.38       112
#            7       0.38      0.82      0.52       535
#            8       0.69      0.14      0.23       185
#            9       1.00      0.02      0.04        87
#           10       0.68      0.34      0.45       214
#           11       0.37      0.80      0.50       537
#           12       0.56      0.21      0.30       272
#           13       0.00      0.00      0.00        40
#           14       0.76      0.22      0.34       119
#           15       0.57      0.48      0.52       265
#           16       0.35      0.86      0.50       876
#           17       0.88      0.41      0.56       220
#           18       0.90      0.29      0.44       266
#           19       0.67      0.06      0.12        95
#           20       0.69      0.39      0.50       207
#           21       0.75      0.21      0.33       156
#           22       0.90      0.31      0.46       148
#           23       0.82      0.38      0.52       175
#           24       0.67      0.05      0.09        79
#           25       0.44      0.24      0.31       200
#           26       0.65      0.34      0.45       345
#
#     accuracy                           0.45      6250
#    macro avg       0.64      0.31      0.35      6250
# weighted avg       0.59      0.45      0.42      6250
#
#
# -----
#
# AdaBoostClassifier
#
# train_time :
# 20.689218759536743
#
# classification_report :
#               precision    recall  f1-score   support
#
#            0       0.49      0.18      0.26       201
#            1       0.41      0.23      0.30       117
#            2       0.65      0.16      0.25       405
#            3       0.39      0.43      0.41       100
#            4       0.00      0.00      0.00       153
#            5       0.41      0.09      0.15       141
#            6       0.43      0.27      0.33       112
#            7       0.67      0.00      0.01       535
#            8       0.00      0.00      0.00       185
#            9       0.00      0.00      0.00        87
#           10       0.62      0.15      0.25       214
#           11       0.20      0.08      0.12       537
#           12       0.35      0.06      0.10       272
#           13       0.50      0.17      0.26        40
#           14       0.55      0.15      0.24       119
#           15       0.40      0.22      0.28       265
#           16       0.16      0.89      0.27       876
#           17       0.84      0.47      0.60       220
#           18       0.89      0.06      0.11       266
#           19       0.43      0.06      0.11        95
#           20       0.53      0.12      0.20       207
#           21       0.50      0.09      0.15       156
#           22       0.00      0.00      0.00       148
#           23       0.78      0.10      0.18       175
#           24       0.29      0.03      0.05        79
#           25       0.40      0.12      0.19       200
#           26       0.00      0.00      0.00       345
#
#     accuracy                           0.22      6250
#    macro avg       0.40      0.15      0.18      6250
# weighted avg       0.39      0.22      0.18      6250
#
#
# -----
#
# GradientBoostingClassifier
#
# train_time :
# 1139.9457986354828
#
# classification_report :
#               precision    recall  f1-score   support
#
#            0       0.61      0.40      0.48       201
#            1       0.31      0.21      0.25       117
#            2       0.55      0.34      0.42       405
#            3       0.39      0.44      0.41       100
#            4       0.31      0.22      0.26       153
#            5       0.45      0.30      0.36       141
#            6       0.45      0.33      0.38       112
#            7       0.59      0.40      0.47       535
#            8       0.50      0.28      0.35       185
#            9       0.18      0.11      0.14        87
#           10       0.57      0.41      0.48       214
#           11       0.44      0.53      0.48       537
#           12       0.42      0.19      0.27       272
#           13       0.33      0.17      0.23        40
#           14       0.42      0.39      0.41       119
#           15       0.49      0.50      0.50       265
#           16       0.28      0.73      0.41       876
#           17       0.78      0.58      0.67       220
#           18       0.71      0.44      0.54       266
#           19       0.47      0.31      0.37        95
#           20       0.65      0.49      0.56       207
#           21       0.54      0.37      0.44       156
#           22       0.63      0.40      0.49       148
#           23       0.55      0.43      0.48       175
#           24       0.16      0.10      0.12        79
#           25       0.39      0.28      0.32       200
#           26       0.59      0.33      0.43       345
#
#     accuracy                           0.43      6250
#    macro avg       0.47      0.36      0.40      6250
# weighted avg       0.48      0.43      0.43      6250
#
#
# -----
#
# XGBClassifier
#
# train_time :
# 153.16305899620056
#
# classification_report :
#               precision    recall  f1-score   support
#
#            0       0.65      0.35      0.46       201
#            1       0.36      0.21      0.26       117
#            2       0.59      0.35      0.44       405
#            3       0.51      0.48      0.49       100
#            4       0.51      0.13      0.21       153
#            5       0.49      0.30      0.37       141
#            6       0.67      0.48      0.56       112
#            7       0.44      0.43      0.43       535
#            8       0.60      0.27      0.37       185
#            9       0.44      0.09      0.15        87
#           10       0.62      0.36      0.46       214
#           11       0.38      0.60      0.47       537
#           12       0.45      0.19      0.27       272
#           13       0.56      0.12      0.20        40
#           14       0.53      0.33      0.40       119
#           15       0.53      0.50      0.51       265
#           16       0.28      0.77      0.41       876
#           17       0.89      0.55      0.68       220
#           18       0.70      0.39      0.50       266
#           19       0.55      0.18      0.27        95
#           20       0.60      0.38      0.46       207
#           21       0.55      0.27      0.36       156
#           22       0.72      0.36      0.48       148
#           23       0.64      0.37      0.47       175
#           24       0.19      0.10      0.13        79
#           25       0.41      0.28      0.34       200
#           26       0.62      0.30      0.40       345
#
#     accuracy                           0.42      6250
#    macro avg       0.53      0.34      0.39      6250
# weighted avg       0.51      0.42      0.42      6250
#
#
# -----
#
# DecisionTreeClassifier
#
# train_time :
# 15.622181177139282
#
# classification_report :
#               precision    recall  f1-score   support
#
#            0       0.30      0.32      0.31       201
#            1       0.21      0.12      0.15       117
#            2       0.35      0.33      0.34       405
#            3       0.30      0.25      0.27       100
#            4       0.22      0.18      0.20       153
#            5       0.36      0.26      0.30       141
#            6       0.44      0.28      0.34       112
#            7       0.29      0.40      0.34       535
#            8       0.23      0.22      0.22       185
#            9       0.21      0.13      0.16        87
#           10       0.30      0.28      0.29       214
#           11       0.29      0.37      0.33       537
#           12       0.14      0.11      0.12       272
#           13       0.00      0.00      0.00        40
#           14       0.23      0.23      0.23       119
#           15       0.34      0.35      0.35       265
#           16       0.43      0.52      0.47       876
#           17       0.64      0.49      0.55       220
#           18       0.40      0.25      0.31       266
#           19       0.18      0.17      0.18        95
#           20       0.33      0.30      0.31       207
#           21       0.25      0.23      0.24       156
#           22       0.37      0.51      0.43       148
#           23       0.26      0.26      0.26       175
#           24       0.10      0.11      0.11        79
#           25       0.22      0.20      0.21       200
#           26       0.30      0.26      0.28       345
#
#     accuracy                           0.32      6250
#    macro avg       0.29      0.26      0.27      6250
# weighted avg       0.32      0.32      0.32      6250
#
#
# -----
#
# MultinomialNB
#
# train_time :
# 0.050461769104003906
#
# classification_report :
#               precision    recall  f1-score   support
#
#            0       0.90      0.04      0.09       201
#            1       0.00      0.00      0.00       117
#            2       0.90      0.11      0.20       405
#            3       0.00      0.00      0.00       100
#            4       0.00      0.00      0.00       153
#            5       1.00      0.01      0.01       141
#            6       0.00      0.00      0.00       112
#            7       0.50      0.62      0.55       535
#            8       0.00      0.00      0.00       185
#            9       0.00      0.00      0.00        87
#           10       1.00      0.02      0.05       214
#           11       0.28      0.77      0.41       537
#           12       0.00      0.00      0.00       272
#           13       0.00      0.00      0.00        40
#           14       0.00      0.00      0.00       119
#           15       0.80      0.06      0.11       265
#           16       0.22      0.99      0.36       876
#           17       1.00      0.04      0.08       220
#           18       1.00      0.03      0.05       266
#           19       0.00      0.00      0.00        95
#           20       1.00      0.04      0.08       207
#           21       0.00      0.00      0.00       156
#           22       1.00      0.01      0.03       148
#           23       0.92      0.07      0.13       175
#           24       0.00      0.00      0.00        79
#           25       1.00      0.04      0.07       200
#           26       0.87      0.06      0.11       345
#
#     accuracy                           0.28      6250
#    macro avg       0.46      0.11      0.09      6250
# weighted avg       0.52      0.28      0.17      6250
#
#
# -----

# %% [markdown]
# # Results Analysis:
# As discussed earlier, the conventional evaluation metrics fail in evaluating the imbalanced dataset classification. We can use precision and recall as a metric to to analyze the performance of our model.
#   Moreover we can see that certain models perform poorly such as DecisionTrees and RandomForest becuase these modles tend to give better result for major classes. While MultinomialNb and SVM perform better because they perfom better for minority classes.

# %% [markdown]
# # Top 3 Models:
# These three are choosen on the based of the results presented in the above sections.
# * SVM
# * Multinomial NB
# * xGBoostCLassifier

# %% [markdown]
# # Optimizing the Hyper-parameters of SVM

# %%
from sklearn.model_selection import GridSearchCV

# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000],
			'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
			'kernel': ['rbf']}

grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)

# fitting the model for grid search
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.142 total time= 1.7min
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.143 total time= 1.6min
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.143 total time= 1.7min
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.144 total time= 1.6min
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.143 total time= 1.6min
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.142 total time= 1.4min
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.142 total time= 1.4min
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.142 total time= 1.4min
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.142 total time= 1.4min
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.142 total time= 1.4min
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.142 total time= 1.2min
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.142 total time= 1.2min
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.142 total time= 1.2min
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.142 total time= 1.2min
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.142 total time= 1.2min
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.142 total time= 1.0min
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.142 total time= 1.0min
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.142 total time= 1.1min
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.142 total time= 1.0min
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.142 total time= 1.0min
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.142 total time= 1.0min
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.142 total time= 1.0min
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.142 total time= 1.0min
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.142 total time= 1.0min
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.142 total time= 1.0min
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.426 total time= 1.7min
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.438 total time= 1.7min
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.423 total time= 1.7min
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.427 total time= 1.7min
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.426 total time= 1.7min
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.274 total time= 1.4min
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.291 total time= 1.4min
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.272 total time= 1.4min
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.282 total time= 1.4min
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.280 total time= 1.4min
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.142 total time= 1.4min
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.142 total time= 1.4min
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.142 total time= 1.3min
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.142 total time= 1.3min
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.142 total time= 1.3min
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.142 total time= 1.2min
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.142 total time= 1.2min
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.142 total time= 1.2min
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.142 total time= 1.2min
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.142 total time= 1.2min
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.142 total time= 1.0min
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.142 total time= 1.0min
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.142 total time= 1.0min
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.142 total time= 1.0min
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.142 total time= 1.0min
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.479 total time= 1.7min
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.481 total time= 1.7min
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.465 total time= 1.7min
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.477 total time= 1.8min
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.474 total time= 1.8min
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.520 total time= 1.6min
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.522 total time= 1.6min
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.505 total time= 1.6min
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.519 total time= 1.6min
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.520 total time= 1.6min
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.304 total time= 1.3min
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.316 total time= 1.3min
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.296 total time= 1.3min
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.312 total time= 1.3min
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.309 total time= 1.3min
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.142 total time= 1.3min
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.142 total time= 1.3min
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.142 total time= 1.3min
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.142 total time= 1.4min
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.142 total time= 1.4min
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.142 total time= 1.2min
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.142 total time= 1.2min
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.142 total time= 1.2min
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.142 total time= 1.2min
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.142 total time= 1.2min
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.479 total time= 1.7min
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.481 total time= 1.7min
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.465 total time= 1.7min
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.477 total time= 1.7min
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.474 total time= 1.8min
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.512 total time= 1.6min
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.514 total time= 1.6min
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.495 total time= 1.6min
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.516 total time= 1.6min
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.512 total time= 1.6min
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.520 total time= 1.5min
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.521 total time= 1.5min
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.504 total time= 1.5min
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.518 total time= 1.6min
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.521 total time= 1.6min
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.307 total time= 1.3min
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.318 total time= 1.4min
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.298 total time= 1.3min
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.315 total time= 1.3min
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.312 total time= 1.3min
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.142 total time= 1.3min
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.142 total time= 1.3min
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.142 total time= 1.3min
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.142 total time= 1.3min
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.142 total time= 1.3min
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.479 total time= 1.7min
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.481 total time= 1.7min
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.465 total time= 1.7min
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.477 total time= 1.7min
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.474 total time= 1.7min
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.512 total time= 1.6min
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.514 total time= 1.6min
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.495 total time= 1.6min
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.516 total time= 1.6min
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.512 total time= 1.6min
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.506 total time= 1.5min
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.513 total time= 1.6min
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.492 total time= 1.5min
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.512 total time= 1.5min
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.510 total time= 1.5min
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.519 total time= 1.5min
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.521 total time= 1.5min
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.503 total time= 1.5min
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.519 total time= 1.5min
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.523 total time= 1.5min
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.307 total time= 1.3min
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.318 total time= 1.3min
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.299 total time= 1.3min
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.316 total time= 1.3min
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.312 total time= 1.3min
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
#@title
# print best parameter after tuning
print(grid.best_params_)

# print how our model looks after hyper-parameter tuning
print(grid.best_estimator_)
# Out:
# {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}
# SVC(C=10, gamma=0.1)

# %%
grid_predictions = grid.predict(x_test)

# print classification report
print(classification_report(y_test, grid_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.43      0.47       201
#            1       0.44      0.22      0.30       117
#            2       0.53      0.52      0.53       405
#            3       0.55      0.45      0.49       100
#            4       0.34      0.27      0.30       153
#            5       0.55      0.43      0.49       141
#            6       0.60      0.48      0.53       112
#            7       0.45      0.72      0.55       535
#            8       0.56      0.29      0.38       185
#            9       0.50      0.16      0.24        87
#           10       0.63      0.51      0.56       214
#           11       0.43      0.70      0.53       537
#           12       0.38      0.33      0.36       272
#           13       0.67      0.10      0.17        40
#           14       0.61      0.44      0.51       119
#           15       0.56      0.58      0.57       265
#           16       0.56      0.75      0.64       876
#           17       0.84      0.51      0.64       220
#           18       0.74      0.44      0.55       266
#           19       0.62      0.31      0.41        95
#           20       0.72      0.59      0.65       207
#           21       0.61      0.44      0.51       156
#           22       0.75      0.64      0.69       148
#           23       0.62      0.54      0.58       175
#           24       0.34      0.16      0.22        79
#           25       0.36      0.33      0.34       200
#           26       0.58      0.48      0.53       345
#
#     accuracy                           0.53      6250
#    macro avg       0.56      0.44      0.47      6250
# weighted avg       0.55      0.53      0.52      6250

# %% [markdown]
# Now we can see that the the overall scores of each class has become better and its working almost good. There are some future suggestions to use LTSM model and to use un-biased dataset which contains equal samples of each class.
